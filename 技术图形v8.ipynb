# %% [markdown]
# # 1. 策略详情
#
# ### 1.1 买入条件
# 1. 多头排列行情；<br><br>
# 2. 两次调整，第二次调整未跌破第一次低点，当第二次调整后的反弹超过第一次高点时<br><br>
# 3. 股价行至五日线之上：收益增加109509
#
# ### 1.2 卖出条件
# 1. 当股价形成新的高点，但对应那天的macd值显著小于上一个高点的macd值<br><br>
#
# ### 1.3 备注
# 1. 止损为m%，止盈为n%<br>

# %% [markdown]
# # 2. 交易程序

# %% [markdown]
# #### 2.1 导入包

# %%
import quantmind as qm
from tabulate import tabulate
import backtrader as bt
import pandas as pd
import numpy as np
import datetime
import random
import time

# %% [markdown]
# #### 2.2 定义策略

# %%
class TechnicalGraphicsStrategy(bt.Strategy):
    params = dict(
        trailamount=0.0,
        trailpercent=0.05,
        stop_loss = -10,         # 止损
        stop_win = 20,           # 止盈
        limit_percent = 1,
        max_hold = 5000,
        )
    def __init__(self):
        self.trade_size = 100000 # 每次买卖的交易量
        self.remarkable = 0.1 # “显著”值
        self.macd_init = 0.123456789
        
        self.ma_5 = dict() # 5日均线
        self.ma_20 = dict() # 20日均线
        self.ma_60 = dict() # 60日均线
        self.macd = dict() # macd线
        self.trend = dict() # 记录股价相对前一天是上涨还是下降
        
        self.low_reversed = dict() # 记录之前是否捕捉到低点
        self.adjust_valid = dict() # 记录是否出现第二次调整
        self.low = dict() # 记录第一次调整低点
        self.high = dict() # 记录第二次调整高点
        self.macd_high = dict() # 记录上一次高点的macd值
        self.orders = dict()
        self.hold = {}
        self.stk = self.datas[1:]
        for data in self.stk:
            self.orders[data] = None
            self.hold[data] = None
            
            self.ma_5[data] = bt.indicators.SMA(data.close, period = 5)
            self.ma_20[data] = bt.indicators.SMA(data.close, period = 20)
            self.ma_60[data] = bt.indicators.SMA(data.close, period = 60)
            self.macd[data] = bt.indicators.MACD(data.close)
            self.trend[data] = bt.indicators.Momentum(data.close, period = 1)
            self.low_reversed[data] = False
            self.adjust_valid[data] = False
            self.high[data] = -1
            self.low[data] = -1
            self.macd_high[data] = 0.123456
            continue
        
    def prenext(self):
        self.next()

    def nextstart(self):
        self.log('Start To Trade.')
        self.next()
             
    def log(self, arg):
        print('{} {}'.format(self.datetime.date(), arg)) 
        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        # 检查订单是否已经执行完成
        # 注意:如果账户资金不够，订单会被拒绝
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            pass
#             self.log('Order Canceled/Margin/Rejected')
        for d in self.stk:
            self.orders[d] = None
        
    def next(self):
        curDate = self.data0.datetime.date(0) # 以第一支股票的时间为基准，避免数据长度不一致问题
        for data in self.stk:
            if curDate != data.datetime.date(0):
                continue
            if self.orders[data]:
                continue
            # 买入
            multi_head = self.ma_5[data][0] > self.ma_20[data][0] and self.ma_20[data][0] > self.ma_60[data][0]
            if multi_head:
                if self.adjust_valid[data] and self.high[data] >= 0 and data.close[0] > self.high[data] and data.close[0]<self.ma_5[data][0] :#是否出现第二次调整，记录第二次调整高点，
                    self.orders[data]=self.buy(data=data, size=self.trade_size)
                    self.low_reversed[data] = False # 状态还原
                    self.adjust_valid[data] = False # 状态还原
                    self.high[data] = -1 # 状态还原
                    self.low[data] = -1 # 状态还原
#                     self.log(" ===BUY CREATE===  CODE:[{}]   PRICE:￥{:0>5}   SHARE:{:>4d}   AMOUNT:￥{:>1f}".\
#                              format(data._name,data.close[0], self.trade_size, self.trade_size*data.close[0]))
                    continue
                    
                if self.trend[data][0]*self.trend[data][-1] < 0 and self.trend[data][0] < 0 and self.low_reversed[data]:#捕捉一个高点
                    self.high[data] = data.close[-1]
                    
                if self.trend[data][0]*self.trend[data][-1] < 0 and self.trend[data][0] > 0:#捕捉一个低点
                    if self.low_reversed[data] and data[-1] > self.low[data]:# 之前捕捉到低点 and 本次低点比上次低点高
                        self.adjust_valid[data] = True # 调整有效，准备捕捉突破点
                        
                    if self.low_reversed[data] and data[-1] <= self.low[data]:# 图形不成立，之前记录的低点作废
                        self.low_reversed[data] = False
                        
                    if not self.low_reversed[data]:# 之前未捕捉到低点
                        self.low[data] = data.close[-1]
                        self.low_reversed[data] = True
            # 卖出
            if self.trend[data][0]*self.trend[data][-1] < 0 and self.trend[data][0] < 0 and self.low_reversed[data]:#捕捉一个高点
                if self.macd_high[data] != self.macd_init and self.getposition(data).size > 0 and\
                    (self.macd_high[data] - self.macd[data][-1])/self.macd_high[data] > self.remarkable: # 之前记录过macd高点，且本次高点“显著小于上次”
                    trade_size = max(self.trade_size, self.getposition(data).size)
                    self.orders[data]=self.sell(data=data, size=self.trade_size)
                    self.macd_high[data] = self.macd_init
#                     self.log("===SELL CREATE===  CODE:[{}]   PRICE:￥{:0>5}   SHARE:{:>4d}   AMOUNT:￥{:>1f}".\
#                              format(data._name,data.close[0], self.trade_size, self.trade_size*data.close[0]))
                    continue
                    
                if self.macd_high[data] == self.macd_init: # 之前未记录过macd高点
                    self.macd_high[data] = self.macd[data][-1]
                    continue
                self.macd_high[data] = self.macd_init
            self.sell_stk(data)
            
    def sell_stk(self,stk):
        ##仓位
        stk_size=self.getposition(stk).size
        
        #持仓成本
    #     if stk_size>0:
        if stk_size>0:#self.hold[stk] is not None and 

            cur_date = stk.datetime.datetime()

            cost = stk_size * self.getposition(stk).price
            # 当前市值
            current_value = stk_size * stk.close[0]
            # 持仓利润
            profit = current_value - cost
            profit_percent = (profit / cost) * 100.0

            if profit_percent < self.p.stop_loss and stk_size>0:
                self.log('- 调出(止损): [%s], 盈亏:%.2f元(%.2f%%), 数量：(%d股)' % (stk._name, profit, profit_percent,stk_size))
                self.orders[stk] = self.sell(data=stk,size=stk_size)
#                 self.hold[stk] = None
            if profit_percent > self.p.stop_win and stk_size>0:
                self.log('- 调出(止盈): [%s], 盈亏:%.2f元(%.2f%%), 数量：(%d股)' % (stk._name, profit, profit_percent,stk_size))
                self.orders[stk] = self.sell(data=stk,size=stk_size)
#                 self.hold[stk] = None

# %% [markdown]
# #### 2.3 主进程

# %%
def prepare_index_data(start_date, end_date):
#     再导入指数的日数据
    index_day = qm.get_bar('000001.SH', start_date=start_date,end_date=end_date, freq='1d')
    index_day['trade_date'] = pd.to_datetime(index_day['trade_date'],format="%Y%m%d")
    dataa = bt.feeds.PandasData(
                dataname=index_day,
                datetime = 'trade_date',
                open=3,
                high=4,
                low=5,
                close=6,
                volume=7,
                openinterest=-1,
                timeframe=bt.TimeFrame.Days,
               )
    cerebro.adddata(dataa, name='index_day')

# %%
class TradeAnalyzer(bt.Analyzer):
    """
    ref - bt's unique trade identifier
    ticker - data feed name
    datein - date and time of trade opening
    pricein - price of trade entry                      买入价
    dir - long or short
    dateout - date and time of trade closing
    priceout - price of trade exit                      卖出价
    chng% - exit price to entry price ratio             卖出价相对买入价的盈利百分比
    pnl - money profit/loss per trade                   盈亏
    pnl% - proft/loss in %s to broker's value at the trade closing  盈亏占交易关闭时账户总值的百分比
    cumpnl - cumulative profit/loss                     累计的盈亏
    size - max position size during trade               交易中最大的成交数量
    value - max trade value                             交易中最大的成交总值
    nbars - trade duration in bars                      交易持续的bar数
    pnl/bar - profit/loss per bar                       平均每根bar的盈亏
    mfe% - max favorable excursion                      最大有利变动幅度
    mae% - max adverse excursion                        最大不利变动幅度
    """

    def get_analysis(self):
        return self.trades

    def __init__(self):
        self.trades = []
        self.cumprofit = 0.0

    def notify_trade(self, trade):
        if trade.isclosed:
            brokervalue = self.strategy.broker.getvalue()
            dir = 'sell'
            if trade.history[0].event.size > 0: dir = 'buy'

            pricein = trade.history[len(trade.history) - 1].status.price
            priceout = trade.history[len(trade.history) - 1].event.price
            datein = bt.num2date(trade.history[0].status.dt)
            dateout = bt.num2date(trade.history[len(trade.history) - 1].status.dt)
            if trade.data._timeframe >= bt.TimeFrame.Days:
                datein = datein.date()
                dateout = dateout.date()

            pcntchange = 100 * priceout / pricein - 100
            pnl = trade.history[len(trade.history) - 1].status.pnlcomm
            pnlpcnt = 100 * pnl / brokervalue
            barlen = trade.history[len(trade.history) - 1].status.barlen
            pbar = pnl / (barlen+1)
            self.cumprofit += pnl

            size = value = 0.0
            for record in trade.history:
                if abs(size) < abs(record.status.size):
                    size = record.status.size
                    value = record.status.value

            highest_in_trade = max(trade.data.high.get(ago=0, size=barlen + 1))
            lowest_in_trade = min(trade.data.low.get(ago=0, size=barlen + 1))
            hp = 100 * (highest_in_trade - pricein) / pricein
            lp = 100 * (lowest_in_trade - pricein) / pricein
            if dir == 'buy':
                mfe = hp
                mae = lp
            if dir == 'sell':
                mfe = -lp
                mae = -hp

            self.trades.append({'ref': trade.ref, 'ticker': trade.data._name,
                                '买入日期': datein, '买入价格': pricein, '卖出日期': dateout, '卖出价格': priceout,
                                'chng%': round(pcntchange, 2), 'pnl': pnl, 'pnl%': round(pnlpcnt, 2),
                                'size': size, 'value': value, 'cumpnl': self.cumprofit,
                                'nbars': barlen, 'pnl/bar': round(pbar, 2),
                                'mfe%': round(mfe, 2), 'mae%': round(mae, 2)})

# %%
# 1. 定义变量
# 1.1 起止时间 
start_date = '20191201'
end_date = '20211201'

# 1.2 费率
capital = 20000000
rate = 0.00015
# 1.3 投资标的
num_stks = 100
all_stk = qm.get_stock_list()
all_stk['list_date']=pd.to_datetime(list(all_stk['list_date']),format="%Y%m%d")
# 剔除上市时间短的股票
all_stk = all_stk[(all_stk['market']!='科创板') & (all_stk['list_date']<'20180101')]
# 剔除ST
all_stk = list(set(all_stk['code'])-set(all_stk[all_stk['name'].str.contains('ST')]['code']))

targets = random.sample(all_stk,num_stks)
print("our stocks:",targets)

# 2. 初始化
# 2.1 创建一个大脑
cerebro = bt.Cerebro()
prepare_index_data(start_date, end_date)

# 2.2 添加投资标的
for target in targets:
    # 载入标的数据
    df = qm.get_bar(target, start_date=start_date, end_date=end_date, freq='1d').sort_values(by='trade_date', ascending=True)
    # 转换数据格式
    df['trade_date1'] = pd.to_datetime(df['trade_date'],format='%Y%m%d') # [int64] --> [date_time]
    data = bt.feeds.PandasData(
        dataname=df,
        datetime = 'trade_date1',
        open=3,
        high=4,
        low=5,
        close=6,
        volume=7,
        openinterest=-1,
        timeframe=bt.TimeFrame.Days,
        )

    # 将数据喂给大脑
    cerebro.adddata(data, name=target)

# 2.3 添加策略
cerebro.addstrategy(TechnicalGraphicsStrategy)

# 2.4 设置初始资金和交易费率
cerebro.broker.setcash(capital)
cerebro.broker.setcommission(commission=rate)
cerebro.addanalyzer(bt.analyzers.AnnualReturn, _name='AnnualReturn')
cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='SharpeRatio')
cerebro.addanalyzer(bt.analyzers.DrawDown, _name='DrawDown')
cerebro.addanalyzer(bt.analyzers.TimeDrawDown, _name='TimeDrawDown')
cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name='Trade')
cerebro.addanalyzer(TradeAnalyzer, _name='trade_list')

# 3. 交易
results = cerebro.run(tradehistory=True)

# 4. 打印结果
result = results[0]
print('Sharpe Ratio:', result.analyzers.SharpeRatio.get_analysis(),
     '\n\nAnnualReturn:', result.analyzers.AnnualReturn.get_analysis(),
     '\n\nTimeDrawDown:', result.analyzers.TimeDrawDown.get_analysis(),
     '\n\nDrawDown:', result.analyzers.DrawDown.get_analysis(),
      '\n\nPnl:', result.analyzers.Trade.get_analysis()['won'],
       '\n\nPnl:', result.analyzers.Trade.get_analysis()['lost']
   )
trade_list = result.analyzers.trade_list.get_analysis()
# print('\n' + tabulate(trade_list, headers="keys") + '\n')
for t in trade_list:
    print(t)
    
print("\n===============================================================")
print('Origin Capital:{:.2f}   Final Capital:{:.2f}   Gain:{:.2f}'\
      .format(capital,cerebro.broker.getvalue(),cerebro.broker.getvalue() - capital))
print("===============================================================")
# Out:
# our stocks: ['601515.SH', '600500.SH', '300549.SZ', '600328.SH', '603855.SH', '600460.SH', '603286.SH', '603881.SH', '002456.SZ', '000565.SZ', '300609.SZ', '000514.SZ', '000408.SZ', '000950.SZ', '002648.SZ', '600663.SH', '000708.SZ', '002478.SZ', '300151.SZ', '002466.SZ', '002479.SZ', '002369.SZ', '600157.SH', '000034.SZ', '002801.SZ', '002798.SZ', '000955.SZ', '002349.SZ', '002705.SZ', '601877.SH', '600496.SH', '002522.SZ', '603030.SH', '002148.SZ', '300293.SZ', '000545.SZ', '300020.SZ', '300242.SZ', '603998.SH', '300235.SZ', '002686.SZ', '000028.SZ', '002124.SZ', '000889.SZ', '601880.SH', '600985.SH', '300326.SZ', '002149.SZ', '601010.SH', '002532.SZ', '300158.SZ', '600561.SH', '603089.SH', '002738.SZ', '600706.SH', '600279.SH', '000567.SZ',
# 2020-07-21 SELL EXECUTED, 7.02
# 2020-07-22 SELL EXECUTED, 18.80
# 2020-07-23 SELL EXECUTED, 6.73
# 2020-07-23 SELL EXECUTED, 5.50
# 2020-07-24 BUY EXECUTED, 16.80
# 2020-07-24 - 调出(止损): [002532.SZ], 盈亏:-113000.00元(-12.60%), 数量：(100000股)
# 2020-07-24 - 调出(止损): [300353.SZ], 盈亏:-144000.00元(-10.94%), 数量：(100000股)
# 2020-07-27 BUY EXECUTED, 17.86
# 2020-07-27 SELL EXECUTED, 7.87
# 2020-07-27 SELL EXECUTED, 11.74
# 2020-07-30 - 调出(止盈): [300443.SZ], 盈亏:491000.00元(20.72%), 数量：(100000股)
# 2020-07-31 SELL EXECUTED, 8.56
# 2020-07-31 SELL EXECUTED, 28.95
# 2020-07-31 - 调出(止盈): [300151.SZ], 盈亏:428000.00元(23.96%), 数量：(100000股)
# 2020-08-03 SELL EXECUTED, 22.95
# 2020-08-05 BUY EXECUTED, 7.97
# 2020-08-05 BUY EXECUTED, 6.00
# 2020-08-06 BUY EXECUTED, 20.56
# 2020-08-07 BUY EXECUTED, 19.88
# 2020-08-10 BUY EXECUTED, 15.33
# 2020-08-10 BUY EXECUTED, 27.20
# 2020-08-10 BUY EXECUTED, 4.40
# 2020-08-11 BUY EXECUTED, 50.76
# 2020-08-12 SELL EXECUTED, 4.26
# 2020-08-13 - 调出(止盈): [002124.SZ], 盈亏:382000.00元(23.85%), 数量：(100000股)
# 2020-08-14 SELL EXECUTED, 19.81
# 2020-08-17 BUY EXECUTED, 16.78
# 2020-08-17 BUY EXECUTED, 10.43
# 2020-08-17 BUY EXECUTED, 1.87
# 2020-08-19 SELL EXECUTED, 8.13
# 2020-08-19 SELL EXECUTED, 15.14
# 2020-08-20 BUY EXECUTED, 4.25
# 2020-08-20 BUY EXECUTED, 31.47
# 2020-08-20 SELL EXECUTED, 24.40
# 2020-08-20 SELL EXECUTED, 16.22
# 2020-08-21 BUY EXECUTED, 5.76
# 2020-08-21 BUY EXECUTED, 8.35
# 2020-08-21 BUY EXECUTED, 24.60
# 2020-08-25 - 调出(止损): [002417.SZ], 盈亏:-117000.00元(-11.22%), 数量：(100000股)
# 2020-08-26 SELL EXECUTED, 19.64
# 2020-08-26 SELL EXECUTED, 9.26
# 2020-08-27 SELL EXECUTED, 6.82
# 2020-09-01 BUY EXECUTED, 19.44
# 2020-09-01 SELL EXECUTED, 5.63
# 2020-09-01 SELL EXECUTED, 8.39
# 2020-09-01 SELL EXECUTED, 48.72
# 2020-09-02 SELL EXECUTED, 8.14
# 2020-09-03 SELL EXECUTED, 15.32
# 2020-09-04 BUY EXECUTED, 5.45
# 2020-09-04 BUY EXECUTED, 14.85
# 2020-09-08 SELL EXECUTED, 18.88
# 2020-09-09 - 调出(止损): [603727.SH], 盈亏:-258000.00元(-12.55%), 数量：(100000股)
# 2020-09-10 BUY EXECUTED, 7.36
# 2020-09-10 BUY EXECUTED, 6.66
# 2020-09-10 BUY EXECUTED, 5.37
# 2020-09-10 SELL EXECUTED, 18.25
# 2020-09-10 - 调出(止损): [300242.SZ], 盈亏:-94000.00元(-12.77%), 数量：(100000股)
# 2020-09-10 - 调出(止损): [300703.SZ], 盈亏:-164000.00元(-11.04%), 数量：(100000股)
# 2020-09-11 BUY EXECUTED, 1.52
# 2020-09-11 SELL EXECUTED, 6.18
# 2020-09-11 BUY EXECUTED, 2.62
# 2020-09-11 SELL EXECUTED, 13.20
# 2020-09-16 SELL EXECUTED, 4.11
# 2020-09-16 BUY EXECUTED, 3.69
# 2020-09-16 SELL EXECUTED, 1.79
# 2020-09-22 SELL EXECUTED, 1.53
# 2020-09-22 SELL EXECUTED, 31.01
# 2020-09-22 SELL EXECUTED, 5.09
# 2020-09-25 SELL EXECUTED, 6.05
# 2020-09-29 SELL EXECUTED, 3.59
# 2020-10-19 BUY EXECUTED, 21.25
# 2020-10-19 BUY EXECUTED, 10.99
# 2020-10-22 BUY EXECUTED, 4.46
# 2020-10-28 - 调出(止盈): [002497.SZ], 盈亏:254000.00元(23.11%), 数量：(100000股)
# 2020-10-29 SELL EXECUTED, 13.21
# 2020-10-29 - 调出(止盈): [600741.SH], 盈亏:615000.00元(25.00%), 数量：(100000股)
# 2020-10-30 SELL EXECUTED, 21.66
# 2020-10-30 BUY EXECUTED, 22.87
# 2020-10-30 SELL EXECUTED, 4.11
# 2020-10-30 SELL EXECUTED, 31.10
# 2020-10-30 - 调出(止损): [002554.SZ], 盈亏:-27000.00元(-10.31%), 数量：(100000股)
# 2020-11-02 SELL EXECUTED, 2.35
# 2020-11-04 SELL EXECUTED, 5.45
# 2020-11-05 BUY EXECUTED, 24.44
# 2020-11-09 SELL EXECUTED, 21.80
# 2020-11-11 SELL EXECUTED, 23.54
# 2020-11-12 BUY EXECUTED, 20.95
# 2020-11-16 BUY EXECUTED, 31.11
# 2020-11-18 BUY EXECUTED, 7.12
# 2020-11-18 - 调出(止损): [000034.SZ], 盈亏:-554000.00元(-17.81%), 数量：(100000股)
# 2020-11-19 BUY EXECUTED, 26.77
# 2020-11-19 SELL EXECUTED, 24.73
# 2020-11-25 BUY EXECUTED, 34.19
# 2020-11-26 BUY EXECUTED, 11.51
# 2020-11-27 BUY EXECUTED, 4.65
# 2020-11-30 - 调出(止损): [002479.SZ], 盈亏:-80000.00元(-11.24%), 数量：(100000股)
# 2020-12-01 SELL EXECUTED, 26.00
# 2020-12-01 SELL EXECUTED, 6.33
# 2020-12-03 SELL EXECUTED, 21.63
# 2020-12-10 BUY EXECUTED, 16.58
# 2020-12-11 BUY EXECUTED, 28.31
# 2020-12-11 - 调出(止盈): [002686.SZ], 盈亏:137000.00元(23.78%), 数量：(100000股)
# 2020-12-14 SELL EXECUTED, 7.30
# 2020-12-17 SELL EXECUTED, 4.47
# 2020-12-17 - 调出(止盈): [002466.SZ], 盈亏:587000.00元(20.73%), 数量：(100000股)
# 2020-12-18 SELL EXECUTED, 33.99
# 2020-12-23 SELL EXECUTED, 34.82
# 2020-12-23 SELL EXECUTED, 10.87
# 2020-12-23 BUY EXECUTED, 34.40
# 2020-12-25 - 调出(止盈): [002497.SZ], 盈亏:422000.00元(25.45%), 数量：(100000股)
# 2020-12-28 SELL EXECUTED, 20.64
# 2021-01-08 BUY EXECUTED, 11.31
# 2021-01-11 BUY EXECUTED, 8.11
# 2021-01-14 SELL EXECUTED, 35.00
# 2021-01-20 BUY EXECUTED, 35.92
# 2021-01-26 BUY EXECUTED, 54.24
# 2021-01-26 - 调出(止损): [000697.SZ], 盈亏:-118000.00元(-10.43%), 数量：(100000股)
# 2021-01-27 SELL EXECUTED, 10.13
# 2021-01-27 - 调出(止盈): [300443.SZ], 盈亏:758000.00元(21.10%), 数量：(100000股)
# 2021-01-28 SELL EXECUTED, 42.45
# 2021-01-29 BUY EXECUTED, 40.70
# 2021-02-01 BUY EXECUTED, 8.80
# 2021-02-04 - 调出(止损): [002500.SZ], 盈亏:-97000.00元(-11.96%), 数量：(100000股)
# 2021-02-05 SELL EXECUTED, 50.11
# 2021-02-05 SELL EXECUTED, 7.14
# 2021-02-05 - 调出(止损): [300443.SZ], 盈亏:-666000.00元(-16.36%), 数量：(100000股)
# 2021-02-08 SELL EXECUTED, 35.78
# 2021-02-24 SELL EXECUTED, 8.50
# 2021-02-26 BUY EXECUTED, 11.23
# 2021-03-01 BUY EXECUTED, 2.17
# 2021-03-08 BUY EXECUTED, 1.57
# 2021-03-09 SELL EXECUTED, 10.40
# 2021-03-15 BUY EXECUTED, 5.73
# 2021-03-15 BUY EXECUTED, 2.75
# 2021-03-17 Start To Trade.
# 2021-03-23 - 调出(止盈): [002554.SZ], 盈亏:75000.00元(27.27%), 数量：(100000股)
# 2021-03-24 SELL EXECUTED, 3.60
# 2021-03-26 BUY EXECUTED, 20.56
# 2021-03-26 - 调出(止盈): [000420.SZ], 盈亏:48000.00元(22.12%), 数量：(100000股)
# 2021-03-29 SELL EXECUTED, 2.65
# 2021-03-30 SELL EXECUTED, 5.55
# 2021-03-31 BUY EXECUTED, 8.63
# 2021-04-01 SELL EXECUTED, 1.54
# 2021-04-02 BUY EXECUTED, 5.30
# 2021-04-14 BUY EXECUTED, 9.54
# 2021-04-14 SELL EXECUTED, 8.55
# 2021-04-14 BUY EXECUTED, 1.73
# 2021-04-16 SELL EXECUTED, 9.79
# 2021-04-21 BUY EXECUTED, 4.27
# 2021-04-22 BUY EXECUTED, 8.07
# 2021-04-22 BUY EXECUTED, 11.88
# 2021-04-26 BUY EXECUTED, 5.21
# 2021-04-26 BUY EXECUTED, 3.06
# 2021-04-26 - 调出(止损): [600706.SH], 盈亏:-82000.00元(-10.16%), 数量：(100000股)
# 2021-04-27 SELL EXECUTED, 7.25
# 2021-04-27 SELL EXECUTED, 1.74
# 2021-04-28 BUY EXECUTED, 1.76
# 2021-04-28 BUY EXECUTED, 5.32
# 2021-04-30 SELL EXECUTED, 19.52
# 2021-05-10 BUY EXECUTED, 32.86
# 2021-05-10 SELL EXECUTED, 4.01
# 2021-05-12 SELL EXECUTED, 5.40
# 2021-07-26 BUY EXECUTED, 64.00
# 2021-07-27 SELL EXECUTED, 27.78
# 2021-07-27 BUY EXECUTED, 18.51
# 2021-07-28 - 调出(止损): [002738.SZ], 盈亏:-1154000.00元(-18.03%), 数量：(100000股)
# 2021-07-28 - 调出(止损): [300340.SZ], 盈亏:-255000.00元(-13.78%), 数量：(100000股)
# 2021-07-29 SELL EXECUTED, 54.49
# 2021-07-29 SELL EXECUTED, 16.30
# 2021-07-30 BUY EXECUTED, 5.82
# 2021-07-30 - 调出(止盈): [300499.SZ], 盈亏:211000.00元(23.24%), 数量：(100000股)
# 2021-08-02 SELL EXECUTED, 15.01
# 2021-08-02 SELL EXECUTED, 11.87
# 2021-08-02 BUY EXECUTED, 23.50
# 2021-08-02 SELL EXECUTED, 11.78
# 2021-08-04 BUY EXECUTED, 34.61
# 2021-08-04 BUY EXECUTED, 5.17
# 2021-08-04 BUY EXECUTED, 60.83
# 2021-08-05 SELL EXECUTED, 5.77
# 2021-08-11 BUY EXECUTED, 28.01
# 2021-08-12 SELL EXECUTED, 11.35
# 2021-08-13 BUY EXECUTED, 52.83
# 2021-08-17 SELL EXECUTED, 32.59
# 2021-08-17 BUY EXECUTED, 9.92
# 2021-08-17 - 调出(止损): [000408.SZ], 盈亏:-374000.00元(-13.35%), 数量：(100000股)
# 2021-08-17 - 调出(止盈): [002270.SZ], 盈亏:131000.00元(25.34%), 数量：(100000股)
# 2021-08-18 SELL EXECUTED, 25.11
# 2021-08-18 BUY EXECUTED, 25.22
# 2021-08-18 SELL EXECUTED, 6.28
# 2021-08-23 SELL EXECUTED, 67.00
# 2021-08-25 BUY EXECUTED, 6.66
# 2021-08-25 BUY EXECUTED, 13.05
# 2021-08-25 - 调出(止盈): [002201.SZ], 盈亏:1264000.00元(25.94%), 数量：(200000股)
# 2021-08-26 SELL EXECUTED, 31.27
# 2021-08-26 SELL EXECUTED, 9.81
# 2021-08-26 - 调出(止盈): [000565.SZ], 盈亏:123000.00元(21.13%), 数量：(100000股)
# 2021-08-27 SELL EXECUTED, 7.00
# 2021-08-27 BUY EXECUTED, 35.03
# 2021-08-27 - 调出(止损): [300499.SZ], 盈亏:-131000.00元(-10.04%), 数量：(100000股)
# 2021-08-30 SELL EXECUTED, 11.86
# 2021-08-31 BUY EXECUTED, 4.76
# 2021-09-02 BUY EXECUTED, 20.20
# 2021-09-02 BUY EXECUTED, 21.80
# 2021-09-03 - 调出(止盈): [300443.SZ], 盈亏:783000.00元(22.35%), 数量：(100000股)
# 2021-09-06 BUY EXECUTED, 12.49
# 2021-09-06 SELL EXECUTED, 44.06
# 2021-09-08 - 调出(止盈): [600328.SH], 盈亏:557000.00元(27.57%), 数量：(100000股)
# 2021-09-09 SELL EXECUTED, 25.78
# 2021-09-09 SELL EXECUTED, 20.88
# 2021-09-13 BUY EXECUTED, 16.80
# 2021-09-13 BUY EXECUTED, 12.15
# 2021-09-13 BUY EXECUTED, 12.62
# 2021-09-13 BUY EXECUTED, 3.38
# 2021-09-14 SELL EXECUTED, 51.80
# 2021-09-14 - 调出(止盈): [002270.SZ], 盈亏:149000.00元(22.37%), 数量：(100000股)
# 2021-09-15 BUY EXECUTED, 126.83
# 2021-09-15 BUY EXECUTED, 6.32
# 2021-09-15 SELL EXECUTED, 8.05
# 2021-09-17 SELL EXECUTED, 110.75
# 2021-09-17 BUY EXECUTED, 7.71
# 2021-09-22 SELL EXECUTED, 16.14
# 2021-09-22 SELL EXECUTED, 5.01
# 2021-09-24 SELL EXECUTED, 8.00
# 2021-09-24 - 调出(止损): [002532.SZ], 盈亏:-144000.00元(-11.85%), 数量：(100000股)
# 2021-09-27 SELL EXECUTED, 10.73
# 2021-09-27 BUY EXECUTED, 5.09
# 2021-09-30 SELL EXECUTED, 14.00
# 2021-09-30 SELL EXECUTED, 6.05
# 2021-10-11 SELL EXECUTED, 4.69
# 2021-10-13 BUY EXECUTED, 7.39
# 2021-10-13 SELL EXECUTED, 12.76
# 2021-10-13 SELL EXECUTED, 3.43
# 2021-10-15 BUY EXECUTED, 5.01
# 2021-10-22 SELL EXECUTED, 7.12
# 2021-10-25 BUY EXECUTED, 3.68
# 2021-10-27 - 调出(止损): [002554.SZ], 盈亏:-37000.00元(-10.05%), 数量：(100000股)
# 2021-10-28 SELL EXECUTED, 3.27
# 2021-11-08 BUY EXECUTED, 34.79
# 2021-11-16 SELL EXECUTED, 33.84
# 2021-11-16 BUY EXECUTED, 9.30
# 2021-11-16 BUY EXECUTED, 23.60
# 2021-11-17 BUY EXECUTED, 17.53
# 2021-11-19 - 调出(止盈): [002270.SZ], 盈亏:218000.00元(23.44%), 数量：(100000股)
# 2021-11-22 SELL EXECUTED, 11.17
# Sharpe Ratio: OrderedDict([('sharperatio', 1.2530327193964932)])
#
# AnnualReturn: OrderedDict([(2019, 0.0), (2020, 0.1336379199999993), (2021, 0.16280107099804852)])
#
# TimeDrawDown: OrderedDict([('maxdrawdown', 10.514143828668965), ('maxdrawdownperiod', 211)])
#
# DrawDown: AutoOrderedDict([('len', 50), ('drawdown', 7.137355738540616), ('moneydown', 2026310.9000000022), ('max', AutoOrderedDict([('len', 211), ('drawdown', 10.514143828668965), ('moneydown', 2541007.350000009)]))])
#
# Pnl: AutoOrderedDict([('total', 57), ('pnl', AutoOrderedDict([('total', 16887980.049999997), ('average', 296280.3517543859), ('max', 1735524.3999999994)]))])
#
# Pnl: AutoOrderedDict([('total', 82), ('pnl', AutoOrderedDict([('total', -10563380.199999997), ('average', -128821.70975609752), ('max', -1611563.6999999997)]))])
# {'ref': 3193, 'ticker': '300169.SZ', '买入日期': datetime.date(2020, 4, 9), '买入价格': 6.82, '卖出日期': datetime.date(2020, 4, 14), '卖出价格': 6.14, 'chng%': -9.97, 'pnl': -68194.40000000005, 'pnl%': -0.34, 'size': 100000, 'value': 682000.0, 'cumpnl': -68194.40000000005, 'nbars': 3, 'pnl/bar': -17048.6, 'mfe%': 1.91, 'mae%': -10.7}
# {'ref': 3267, 'ticker': '600496.SH', '买入日期': datetime.date(2021, 3, 15), '买入价格': 5.73, '卖出日期': datetime.date(2021, 3, 30), '卖出价格': 5.55, 'chng%': -3.14, 'pnl': -18169.200000000063, 'pnl%': -0.08, 'size': 100000, 'value': 573000.0, 'cumpnl': 2374874.3499999996, 'nbars': 11, 'pnl/bar': -1514.1, 'mfe%': 2.27, 'mae%': -8.03}
# {'ref': 3266, 'ticker': '600022.SH', '买入日期': datetime.date(2021, 3, 8), '买入价格': 1.57, '卖出日期': datetime.date(2021, 4, 1), '卖出价格': 1.54, 'chng%': -1.91, 'pnl': -3046.650000000003, 'pnl%': -0.01, 'size': 100000, 'value': 157000.0, 'cumpnl': 2371827.6999999997, 'nbars': 18, 'pnl/bar': -160.35, 'mfe%': 12.74, 'mae%': -7.01}
# {'ref': 3270, 'ticker': '300169.SZ', '买入日期': datetime.date(2021, 3, 31), '买入价格': 8.63, '卖出日期': datetime.date(2021, 4, 14), '卖出价格': 8.55, 'chng%': -0.93, 'pnl': -8257.700000000008, 'pnl%': -0.04, 'size': 100000, 'value': 863000.0000000001, 'cumpnl': 2363569.9999999995, 'nbars': 9, 'pnl/bar': -825.77, 'mfe%': 1.97, 'mae%': -6.26}
# {'ref': 3272, 'ticker': '000567.SZ', '买入日期': datetime.date(2021, 4, 14), '买入价格': 9.54, '卖出日期': datetime.date(2021, 4, 16), '卖出价格': 9.79, 'chng%': 2.62, 'pnl': 24710.05, 'pnl%': 0.11, 'size': 100000, 'value': 953999.9999999999, 'cumpnl': 2388280.0499999993, 'nbars': 2, 'pnl/bar': 8236.68, 'mfe%': 8.7, 'mae%': 0.0}
# {'ref': 3275, 'ticker': '600706.SH', '买入日期': datetime.date(2021, 4, 22), '买入价格': 8.07, '卖出日期': datetime.date(2021, 4, 27), '卖出价格': 7.25, 'chng%': -10.16, 'pnl': -82229.80000000003, 'pnl%': -0.37, 'size': 100000, 'value': 807000.0, 'cumpnl': 2306050.2499999995, 'nbars': 3, 'pnl/bar': -20557.45, 'mfe%': 0.74, 'mae%': -13.63}
# {'ref': 3273, 'ticker': '600022.SH', '买入日期': datetime.date(2021, 4, 14), '买入价格': 1.73, '卖出日期': datetime.date(2021, 4, 27), '卖出价格': 1.74, 'chng%': 0.58, 'pnl': 947.950000000001, 'pnl%': 0.0, 'size': 100000, 'value': 173000.0, 'cumpnl': 2306998.1999999997, 'nbars': 9, 'pnl/bar': 94.8, 'mfe%': 6.94, 'mae%': -3.47}
# {'ref': 3269, 'ticker': '603855.SH', '买入日期': datetime.date(2021, 3, 26), '买入价格': 20.56, '卖出日期': datetime.date(2021, 4, 30), '卖出价格': 19.52, 'chng%': -5.06, 'pnl': -104601.19999999991, 'pnl%': -0.47, 'size': 100000, 'value': 2055999.9999999998, 'cumpnl': 2202397.0, 'nbars': 24, 'pnl/bar': -4184.05, 'mfe%': 2.04, 'mae%': -9.63}
# {'ref': 3274, 'ticker': '002148.SZ', '买入日期': datetime.date(2021, 4, 21), '买入价格': 4.27, '卖出日期': datetime.date(2021, 5, 10), '卖出价格': 4.01, 'chng%': -6.09, 'pnl': -26124.19999999998, 'pnl%': -0.12, 'size': 100000, 'value': 426999.99999999994, 'cumpnl': 2176272.8, 'nbars': 10, 'pnl/bar': -2374.93, 'mfe%': 1.64, 'mae%': -7.96}
# {'ref': 3271, 'ticker': '002369.SZ', '买入日期': datetime.date(2021, 4, 2), '买入价格': 5.3, '卖出日期': datetime.date(2021, 5, 12), '卖出价格': 5.4, 'chng%': 1.89, 'pnl': 9839.500000000053, 'pnl%': 0.04, 'size': 100000, 'value': 530000.0, 'cumpnl': 2186112.3, 'nbars': 24, 'pnl/bar': 393.58, 'mfe%': 22.45, 'mae%': -3.96}
# {'ref': 3286, 'ticker': '000408.SZ', '买入日期': datetime.date(2021, 5, 18), '买入价格': 14.58, '卖出日期': datetime.date(2021, 5, 21), '卖出价格': 17.58, 'chng%': 20.58, 'pnl': 299517.5999999998, 'pnl%': 1.3, 'size': 100000, 'value': 1458000.0, 'cumpnl': 2485629.8999999994, 'nbars': 3, 'pnl/bar': 74879.4, 'mfe%': 34.22, 'mae%': -0.55}
# {'ref': 3276, 'ticker': '002201.SZ', '买入日期': datetime.date(2021, 4, 22), '买入价格': 11.88, '卖出日期': datetime.date(2021, 5, 26), '卖出价格': 14.8, 'chng%': 24.58, 'pnl': 291599.8, 'pnl%': 1.24, 'size': 100000, 'value': 1188000.0, 'cumpnl': 2777229.6999999993, 'nbars': 21, 'pnl/bar': 13254.54, 'mfe%': 27.19, 'mae%': -1.52}
# {'ref': 3278, 'ticker': '601010.SH', '买入日期': datetime.date(2021, 4, 26), '买入价格': 3.06, '卖出日期': datetime.date(2021, 5, 27), '卖出价格': 3.25, 'chng%': 6.21, 'pnl': 18905.349999999995, 'pnl%': 0.08, 'size': 100000, 'value': 306000.0, 'cumpnl': 2796135.0499999993, 'nbars': 20, 'pnl/bar': 900.25, 'mfe%': 9.15, 'mae%': -1.96}
# {'ref': 3277, 'ticker': '000950.SZ', '买入日期': datetime.date(2021, 4, 26), '买入价格': 5.21, '卖出日期': datetime.date(2021, 5, 28), '卖出价格': 5.38, 'chng%': 3.26, 'pnl': 16841.149999999994, 'pnl%': 0.07, 'size': 100000, 'value': 521000.0, 'cumpnl': 2812976.1999999993, 'nbars': 21, 'pnl/bar': 765.51, 'mfe%': 17.27, 'mae%': -2.11}
# {'ref': 3285, 'ticker': '601515.SH', '买入日期': datetime.date(2021, 5, 17), '买入价格': 6.89, '卖出日期': datetime.date(2021, 5, 31), '卖出价格': 6.08, 'chng%': -11.76, 'pnl': -81194.54999999996, 'pnl%': -0.34, 'size': 100000, 'value': 689000.0, 'cumpnl': 2731781.6499999994, 'nbars': 10, 'pnl/bar': -7381.32, 'mfe%': 5.81, 'mae%': -11.76}
# {'ref': 3279, 'ticker': '600157.SH', '买入日期': datetime.date(2021, 4, 28), '买入价格': 1.76, '卖出日期': datetime.date(2021, 5, 31), '卖出价格': 1.62, 'chng%': -7.95, 'pnl': -14050.699999999992, 'pnl%': -0.06, 'size': 100000, 'value': 176000.0, 'cumpnl': 2717730.9499999993, 'nbars': 19, 'pnl/bar': -702.53, 'mfe%': 7.39, 'mae%': -10.23}
# {'ref': 3281, 'ticker': '600460.SH', '买入日期': datetime.date(2021, 5, 10), '买入价格': 32.86, '卖出日期': datetime.date(2021, 6, 1), '卖出价格': 39.08, 'chng%': 18.93, 'pnl': 620920.8999999999, 'pnl%': 2.63, 'size': 100000, 'value': 3286000.0, 'cumpnl': 3338651.849999999, 'nbars': 16, 'pnl/bar': 36524.76, 'mfe%': 25.81, 'mae%': -4.75}
# {'ref': 3282, 'ticker': '000545.SZ', '买入日期': datetime.date(2021, 5, 12), '买入价格': 3.48, '卖出日期': datetime.date(2021, 6, 2), '卖出价格': 3.47, 'chng%': -0.29, 'pnl': -1104.2499999999786, 'pnl%': -0.0, 'size': 100000, 'value': 348000.0, 'cumpnl': 3337547.599999999, 'nbars': 15, 'pnl/bar': -69.02, 'mfe%': 12.64, 'mae%': -6.61}
# {'ref': 3280, 'ticker': '300158.SZ', '买入日期': datetime.date(2021, 4, 28), '买入价格': 5.32, '卖出日期': datetime.date(2021, 6, 3), '卖出价格': 7.2, 'chng%': 35.34, 'pnl': 187812.2, 'pnl%': 0.79, 'size': 100000, 'value': 532000.0, 'cumpnl': 3525359.7999999993, 'nbars': 23, 'pnl/bar': 7825.51, 'mfe%': 36.09, 'mae%': -4.7}
# {'ref': 3287, 'ticker': '300660.SZ', '买入日期': datetime.date(2021, 5, 18), '买入价格': 19.85, '卖出日期': datetime.date(2021, 6, 3), '卖出价格': 19.61, 'chng%': -1.21, 'pnl': -24591.9000000002, 'pnl%': -0.1, 'size': 100000, 'value': 1985000.0000000002, 'cumpnl': 3500767.899999999, 'nbars': 12, 'pnl/bar': -1891.68, 'mfe%': 9.02, 'mae%': -2.07}
# {'ref': 3288, 'ticker': '300326.SZ', '买入日期': datetime.date(2021, 5, 21), '买入价格': 13.05, '卖出日期': datetime.date(2021, 6, 10), '卖出价格': 12.69, 'chng%': -2.76, 'pnl': -36386.10000000012, 'pnl%': -0.15, 'size': 100000, 'value': 1305000.0, 'cumpnl': 3464381.799999999, 'nbars': 14, 'pnl/bar': -2425.74, 'mfe%': 11.19, 'mae%': -6.21}
# {'ref': 3284, 'ticker': '600500.SH', '买入日期': datetime.date(2021, 5, 14), '买入价格': 6.03, '卖出日期': datetime.date(2021, 6, 15), '卖出价格': 7.32, 'chng%': 21.39, 'pnl': 128799.75, 'pnl%': 0.55, 'size': 100000, 'value': 603000.0, 'cumpnl': 3593181.549999999, 'nbars': 21, 'pnl/bar': 5854.53, 'mfe%': 25.04, 'mae%': -2.32}
# {'ref': 3289, 'ticker': '000565.SZ', '买入日期': datetime.date(2021, 5, 25), '买入价格': 5.68, '卖出日期': datetime.date(2021, 6, 17), '卖出价格': 5.68, 'chng%': 0.0, 'pnl': -170.39999999999998, 'pnl%': -0.0, 'size': 100000, 'value': 568000.0, 'cumpnl': 3593011.149999999, 'nbars': 16, 'pnl/bar': -10.02, 'mfe%': 12.85, 'mae%': -2.29}
# {'ref': 3297, 'ticker': '600328.SH', '买入日期': datetime.date(2021, 7, 2), '买入价格': 13.1, '卖出日期': datetime.date(2021, 7, 13), '卖出价格': 16.39, 'chng%': 25.11, 'pnl': 328557.65000000014, 'pnl%': 1.28, 'size': 100000, 'value': 1310000.0, 'cumpnl': 5389587.449999999, 'nbars': 7, 'pnl/bar': 41069.71, 'mfe%': 35.19, 'mae%': -0.31}
# {'ref': 3296, 'ticker': '600460.SH', '买入日期': datetime.date(2021, 7, 1), '买入价格': 59.49, '卖出日期': datetime.date(2021, 7, 26), '卖出价格': 63.65, 'chng%': 6.99, 'pnl': 414152.8999999997, 'pnl%': 1.56, 'size': 100000, 'value': 5949000.0, 'cumpnl': 5803740.349999999, 'nbars': 17, 'pnl/bar': 23008.49, 'mfe%': 14.64, 'mae%': -11.73}
# {'ref': 3299, 'ticker': '002497.SZ', '买入日期': datetime.date(2021, 7, 15), '买入价格': 27.06, '卖出日期': datetime.date(2021, 7, 27), '卖出价格': 27.78, 'chng%': 2.66, 'pnl': 71177.40000000024, 'pnl%': 0.28, 'size': 100000, 'value': 2706000.0, 'cumpnl': 5874917.749999999, 'nbars': 8, 'pnl/bar': 7908.6, 'mfe%': 12.71, 'mae%': -7.13}
# {'ref': 3303, 'ticker': '002738.SZ', '买入日期': datetime.date(2021, 7, 26), '买入价格': 64.0, '卖出日期': datetime.date(2021, 7, 29), '卖出价格': 54.49, 'chng%': -14.86, 'pnl': -952777.3499999997, 'pnl%': -3.8, 'size': 100000, 'value': 6400000.0, 'cumpnl': 4922140.399999999, 'nbars': 3, 'pnl/bar': -238194.34, 'mfe%': 3.91, 'mae%': -18.03}
# {'ref': 3304, 'ticker': '300340.SZ', '买入日期': datetime.date(2021, 7, 27), '买入价格': 18.51, '卖出日期': datetime.date(2021, 7, 29), '卖出价格': 16.3, 'chng%': -11.94, 'pnl': -221522.15000000008, 'pnl%': -0.88, 'size': 100000, 'value': 1851000.0000000002, 'cumpnl': 4700618.249999999, 'nbars': 2, 'pnl/bar': -73840.72, 'mfe%': 1.84, 'mae%': -18.04}
# {'ref': 3301, 'ticker': '600328.SH', '买入日期': datetime.date(2021, 7, 20), '买入价格': 16.5, '卖出日期': datetime.date(2021, 8, 2), '卖出价格': 15.01, 'chng%': -9.03, 'pnl': -149472.65000000002, 'pnl%': -0.6, 'size': 100000, 'value': 1650000.0, 'cumpnl': 4551145.599999999, 'nbars': 9, 'pnl/bar': -14947.27, 'mfe%': 18.18, 'mae%': -11.45}
# {'ref': 3300, 'ticker': '300499.SZ', '买入日期': datetime.date(2021, 7, 15), '买入价格': 9.08, '卖出日期': datetime.date(2021, 8, 2), '卖出价格': 11.78, 'chng%': 29.74, 'pnl': 269687.0999999999, 'pnl%': 1.08, 'size': 100000, 'value': 908000.0, 'cumpnl': 4820832.699999998, 'nbars': 12, 'pnl/bar': 20745.16, 'mfe%': 34.25, 'mae%': -4.74}
# {'ref': 3302, 'ticker': '002349.SZ', '买入日期': datetime.date(2021, 7, 23), '买入价格': 5.48, '卖出日期': datetime.date(2021, 8, 5), '卖出价格': 5.77, 'chng%': 5.29, 'pnl': 28831.249999999916, 'pnl%': 0.11, 'size': 100000, 'value': 548000.0, 'cumpnl': 4849663.949999998, 'nbars': 9, 'pnl/bar': 2883.12, 'mfe%': 10.04, 'mae%': -8.94}
# {'ref': 3295, 'ticker': '000567.SZ', '买入日期': datetime.date(2021, 6, 30), '买入价格': 11.02, '卖出日期': datetime.date(2021, 8, 12), '卖出价格': 11.35, 'chng%': 2.99, 'pnl': 117321.09999999998, 'pnl%': 0.46, 'size': 200000, 'value': 2204000.0, 'cumpnl': 4966985.049999998, 'nbars': 31, 'pnl/bar': 3666.28, 'mfe%': 17.79, 'mae%': -4.99}
# {'ref': 3307, 'ticker': '300443.SZ', '买入日期': datetime.date(2021, 8, 4), '买入价格': 34.61, '卖出日期': datetime.date(2021, 8, 17), '卖出价格': 32.59, 'chng%': -5.84, 'pnl': -203007.9999999996, 'pnl%': -0.82, 'size': 100000, 'value': 3461000.0, 'cumpnl': 4763977.049999998, 'nbars': 9, 'pnl/bar': -20300.8, 'mfe%': 8.12, 'mae%': -6.39}
# {'ref': 3310, 'ticker': '000408.SZ', '买入日期': datetime.date(2021, 8, 11), '买入价格': 28.01, '卖出日期': datetime.date(2021, 8, 18), '卖出价格': 25.11, 'chng%': -10.35, 'pnl': -290796.8000000002, 'pnl%': -1.17, 'size': 100000, 'value': 2801000.0, 'cumpnl': 4473180.249999998, 'nbars': 5, 'pnl/bar': -48466.13, 'mfe%': 3.78, 'mae%': -13.35}
# {'ref': 3308, 'ticker': '002270.SZ', '买入日期': datetime.date(2021, 8, 4), '买入价格': 5.17, '卖出日期': datetime.date(2021, 8, 18), '卖出价格': 6.28, 'chng%': 21.47, 'pnl': 110828.25000000003, 'pnl%': 0.44, 'size': 100000, 'value': 517000.0, 'cumpnl': 4584008.499999998, 'nbars': 10, 'pnl/bar': 10075.3, 'mfe%': 37.91, 'mae%': -3.29}
# {'ref': 3309, 'ticker': '002025.SZ', '买入日期': datetime.date(2021, 8, 4), '买入价格': 60.83, '卖出日期': datetime.date(2021, 8, 23), '卖出价格': 67.0, 'chng%': 10.14, 'pnl': 615082.5500000002, 'pnl%': 2.4, 'size': 100000, 'value': 6083000.0, 'cumpnl': 5199091.049999998, 'nbars': 13, 'pnl/bar': 43934.47, 'mfe%': 16.03, 'mae%': -0.97}
# {'ref': 3306, 'ticker': '002201.SZ', '买入日期': datetime.date(2021, 8, 2), '买入价格': 24.36, '卖出日期': datetime.date(2021, 8, 26), '卖出价格': 31.27, 'chng%': 28.37, 'pnl': 1380331.1, 'pnl%': 5.14, 'size': 200000, 'value': 4872000.0, 'cumpnl': 6579422.1499999985, 'nbars': 18, 'pnl/bar': 72649.01, 'mfe%': 30.46, 'mae%': -10.06}
# {'ref': 3312, 'ticker': '000697.SZ', '买入日期': datetime.date(2021, 8, 17), '买入价格': 9.92, '卖出日期': datetime.date(2021, 8, 26), '卖出价格': 9.81, 'chng%': -1.11, 'pnl': -11295.949999999944, 'pnl%': -0.04, 'size': 100000, 'value': 992000.0, 'cumpnl': 6568126.199999998, 'nbars': 7, 'pnl/bar': -1411.99, 'mfe%': 14.82, 'mae%': -5.54}
# {'ref': 3305, 'ticker': '000565.SZ', '买入日期': datetime.date(2021, 7, 30), '买入价格': 5.82, '卖出日期': datetime.date(2021, 8, 27), '卖出价格': 7.0, 'chng%': 20.27, 'pnl': 117807.69999999997, 'pnl%': 0.44, 'size': 100000, 'value': 582000.0, 'cumpnl': 6685933.8999999985, 'nbars': 20, 'pnl/bar': 5609.89, 'mfe%': 25.43, 'mae%': 0.0}
# {'ref': 3314, 'ticker': '300499.SZ', '买入日期': datetime.date(2021, 8, 25), '买入价格': 13.05, '卖出日期': datetime.date(2021, 8, 30), '卖出价格': 11.86, 'chng%': -9.12, 'pnl': -119373.65000000013, 'pnl%': -0.44, 'size': 100000, 'value': 1305000.0, 'cumpnl': 6566560.249999998, 'nbars': 3, 'pnl/bar': -29843.41, 'mfe%': 3.3, 'mae%': -10.88}
# {'ref': 3315, 'ticker': '300443.SZ', '买入日期': datetime.date(2021, 8, 27), '买入价格': 35.03, '卖出日期': datetime.date(2021, 9, 6), '卖出价格': 44.06, 'chng%': 25.78, 'pnl': 901813.6500000001, 'pnl%': 3.25, 'size': 100000, 'value': 3503000.0, 'cumpnl': 7468373.8999999985, 'nbars': 6, 'pnl/bar': 128830.52, 'mfe%': 32.74, 'mae%': -8.48}
# {'ref': 3317, 'ticker': '600328.SH', '买入日期': datetime.date(2021, 9, 2), '买入价格': 20.2, '卖出日期': datetime.date(2021, 9, 9), '卖出价格': 25.78, 'chng%': 27.62, 'pnl': 557310.3000000003, 'pnl%': 1.98, 'size': 100000, 'value': 2020000.0, 'cumpnl': 8025684.199999999, 'nbars': 5, 'pnl/bar': 92885.05, 'mfe%': 37.33, 'mae%': -0.45}
# {'ref': 3318, 'ticker': '002149.SZ', '买入日期': datetime.date(2021, 9, 2), '买入价格': 21.8, '卖出日期': datetime.date(2021, 9, 9), '卖出价格': 20.88, 'chng%': -4.22, 'pnl': -92640.20000000017, 'pnl%': -0.33, 'size': 100000, 'value': 2180000.0, 'cumpnl': 7933043.999999999, 'nbars': 5, 'pnl/bar': -15440.03, 'mfe%': 5.96, 'mae%': -10.37}
# {'ref': 3311, 'ticker': '601877.SH', '买入日期': datetime.date(2021, 8, 13), '买入价格': 52.83, '卖出日期': datetime.date(2021, 9, 14), '卖出价格': 51.8, 'chng%': -1.95, 'pnl': -104569.45000000011, 'pnl%': -0.37, 'size': 100000, 'value': 5283000.0, 'cumpnl': 7828474.549999999, 'nbars': 22, 'pnl/bar': -4546.5, 'mfe%': 21.37, 'mae%': -9.31}
# {'ref': 3313, 'ticker': '002270.SZ', '买入日期': datetime.date(2021, 8, 25), '买入价格': 6.66, '卖出日期': datetime.date(2021, 9, 15), '卖出价格': 8.05, 'chng%': 20.87, 'pnl': 138779.35000000006, 'pnl%': 0.49, 'size': 100000, 'value': 666000.0, 'cumpnl': 7967253.8999999985, 'nbars': 15, 'pnl/bar': 8673.71, 'mfe%': 25.98, 'mae%': -1.2}
# {'ref': 3327, 'ticker': '000420.SZ', '买入日期': datetime.date(2021, 9, 27), '买入价格': 5.09, '卖出日期': datetime.date(2021, 10, 11), '卖出价格': 4.69, 'chng%': -7.86, 'pnl': -40146.699999999946, 'pnl%': -0.15, 'size': 100000, 'value': 509000.0, 'cumpnl': 6283741.1, 'nbars': 5, 'pnl/bar': -6691.12, 'mfe%': 0.2, 'mae%': -16.9}
# {'ref': 3322, 'ticker': '000985.SZ', '买入日期': datetime.date(2021, 9, 13), '买入价格': 12.62, '卖出日期': datetime.date(2021, 10, 13), '卖出价格': 12.76, 'chng%': 1.11, 'pnl': 13619.300000000056, 'pnl%': 0.05, 'size': 100000, 'value': 1262000.0, 'cumpnl': 6297360.399999999, 'nbars': 15, 'pnl/bar': 851.21, 'mfe%': 8.8, 'mae%': -6.5}
# {'ref': 3323, 'ticker': '601107.SH', '买入日期': datetime.date(2021, 9, 13), '买入价格': 3.38, '卖出日期': datetime.date(2021, 10, 13), '卖出价格': 3.43, 'chng%': 1.48, 'pnl': 4897.850000000027, 'pnl%': 0.02, 'size': 100000, 'value': 338000.0, 'cumpnl': 6302258.249999999, 'nbars': 15, 'pnl/bar': 306.12, 'mfe%': 6.21, 'mae%': -1.78}
# {'ref': 3328, 'ticker': '002369.SZ', '买入日期': datetime.date(2021, 10, 13), '买入价格': 7.39, '卖出日期': datetime.date(2021, 10, 22), '卖出价格': 7.12, 'chng%': -3.65, 'pnl': -27217.649999999958, 'pnl%': -0.1, 'size': 100000, 'value': 739000.0, 'cumpnl': 6275040.599999999, 'nbars': 7, 'pnl/bar': -3402.21, 'mfe%': 3.25, 'mae%': -8.12}
# {'ref': 3330, 'ticker': '002554.SZ', '买入日期': datetime.date(2021, 10, 25), '买入价格': 3.68, '卖出日期': datetime.date(2021, 10, 28), '卖出价格': 3.27, 'chng%': -11.14, 'pnl': -41104.250000000015, 'pnl%': -0.16, 'size': 100000, 'value': 368000.0, 'cumpnl': 6233936.349999999, 'nbars': 3, 'pnl/bar': -10276.06, 'mfe%': 2.17, 'mae%': -14.67}
# {'ref': 3331, 'ticker': '300660.SZ', '买入日期': datetime.date(2021, 11, 8), '买入价格': 34.79, '卖出日期': datetime.date(2021, 11, 16), '卖出价格': 33.84, 'chng%': -2.73, 'pnl': -96029.44999999958, 'pnl%': -0.37, 'size': 100000, 'value': 3479000.0, 'cumpnl': 6137906.899999999, 'nbars': 6, 'pnl/bar': -13718.49, 'mfe%': 7.79, 'mae%': -6.93}
# {'ref': 3332, 'ticker': '002270.SZ', '买入日期': datetime.date(2021, 11, 16), '买入价格': 9.3, '卖出日期': datetime.date(2021, 11, 22), '卖出价格': 11.17, 'chng%': 20.11, 'pnl': 186692.94999999992, 'pnl%': 0.71, 'size': 100000, 'value': 930000.0000000001, 'cumpnl': 6324599.85, 'nbars': 4, 'pnl/bar': 37338.59, 'mfe%': 26.24, 'mae%': -6.34}
#
# ===============================================================
# Origin Capital:20000000.00   Final Capital:26363907.75   Gain:6363907.75
# ===============================================================
